# %%
import pandas as pd
# Out:
# Running cells with 'env (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/rushitechnologies/Desktop/AI engineer session batch 1/dataAnalysis/env/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %%
import ipykernel

# %%
import numpy as np
